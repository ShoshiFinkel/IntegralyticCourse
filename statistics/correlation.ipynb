# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [2,3,5,1,0,7,6,4]
y = [25,27,30,24,22,38,33,29]
df = pd.DataFrame(zip(x,y), columns=('years','salary'))
df
# Out:
#    years  salary
# 0      2      25
# 1      3      27
# 2      5      30
# 3      1      24
# 4      0      22
# 5      7      38
# 6      6      33
# 7      4      29

# %%
sns.lmplot(x="years", y="salary", data=df)
plt.show()
print(df.corr())
# Out:
#            years    salary
# years   1.000000  0.973908
# salary  0.973908  1.000000
