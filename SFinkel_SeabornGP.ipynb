# %% [markdown]
# ## Seaborn Guided Project
# #### Shoshi Finkel

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
hotel_bookings = pd.read_csv("hotel_bookings.csv")

# %%
# Explore the data
hotel_bookings.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#Describe the data
hotel_bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Print info about the data
hotel_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Find the nulls values
hotel_bookings.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
#  Dropping the company and the agent columns, seems unnecessary because they have a lot of nulls.
hotel_bookings.drop(hotel_bookings[['company', 'agent']], axis=1, inplace=True)

# %%
# Check the changes.
hotel_bookings.shape
# Out:
# (119390, 30)

# %%
# Count the values in the country column.
hotel_bookings['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
# Replace the nulls with 'PRT', because this is the common country.
hotel_bookings['country'] =hotel_bookings['country'].fillna('PRT')

# %%
# Check if there are still nulls.
hotel_bookings['country'].isnull().sum()
# Out:
# 0

# %%
# Replace the nulls in the children column to 0 because there are only 4 nulls.
hotel_bookings['children'] =hotel_bookings['children'].fillna(0)

# %%
# Check if there are still nulls.
hotel_bookings['children'].isnull().sum()
# Out:
# 0

# %%
# Change the month's names to numbers
hotel_bookings['arrival_date_month'] = hotel_bookings['arrival_date_month'].map({'January' : 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November': 11, 'December':12})

# %%
# Create a column of arrival date, including day, month and year.
hotel_bookings['arrival_date'] =pd.to_datetime(dict(year=hotel_bookings.arrival_date_year, month=hotel_bookings.arrival_date_month, day=hotel_bookings.arrival_date_day_of_month))

# %%
#Find the correlation between lead time and is canceles.
sns.heatmap(data=hotel_bookings[['lead_time','is_canceled']].corr(),annot=True, cmap='Purples')
plt.suptitle("Lead time Impacting Cancellations")
# Out:
# Text(0.5, 0.98, 'Lead time Impacting Cancellations')

# %% [markdown]
# From the heatmap, we see that there is almost no correlation between the lead time and the bookings that were canceled.

# %%
# Create a data frame with the bookings that weren't canceled.
hotel_bookings_not_canceled = hotel_bookings[hotel_bookings['is_canceled']==0]
hotel_bookings_not_canceled.shape
# Out:
# (75166, 31)

# %%
# Print the columns names.
hotel_bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'arrival_date'],
#       dtype='object')

# %%
# Create a catplot to find the booking per month for each hotel.
sns.catplot(data = hotel_bookings_not_canceled, x = 'arrival_date_month', col= 'hotel', kind= 'count',palette='rainbow')
plt.suptitle("Booking Per Month", y=1.05)
# Out:
# Text(0.5, 1.05, 'Booking Per Month')

# %% [markdown]
# We see that generally there are more bookings in the City Hotel. In the two hotels, the highest season is August, and September and January are the lowest seasons, in the Resort Hotel also June, September and November are low.

# %%
# Create a catplot to find the booking per year for each hotel.
sns.catplot(data = hotel_bookings_not_canceled, x = 'arrival_date_year', col='hotel', kind= 'count',palette='rainbow')
plt.suptitle("Booking Per Year",y=1.05)
# Out:
# Text(0.5, 1.05, 'Booking Per Year')

# %% [markdown]
# We can see that both hotels had the most bookings in 2016.

# %%
# Create a relplot to find the customer's type, if they're repeated guasts, the distribution channel the booking changes and the lead time.
sns.relplot(data=hotel_bookings_not_canceled, x="lead_time", y="booking_changes",hue = 'customer_type', style='distribution_channel', size='is_repeated_guest', col='hotel',
 sizes= (15, 200))
plt.suptitle("Booking Per Year")
plt.show()

# %% [markdown]
# From the relplot we see that as the lead time is later there are more booking changes. That most of the guests are repeated guests. The most popular distribution channel is TA/TO. Most of the customers are Transient.

# %%
# A function to make a column of locals and of people from other places.
def local(x):
    if x == 'PRT':
        return 'local'
    else:
        return 'Out of town'

# %%
# Apply the function.
hotel_bookings_not_canceled['local'] = hotel_bookings_not_canceled['country'].apply(local)
# Out:
# C:\Users\The user\AppData\Local\Temp\ipykernel_2664\1651220837.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_bookings_not_canceled['local'] = hotel_bookings_not_canceled['country'].apply(local)

# %%
# Create a catplot to find how many people in each hotel are locals and how many are not.
sns.catplot(data=hotel_bookings_not_canceled, x='local', kind='count', hue='hotel')
plt.suptitle("Count the locals in each hotel")
# Out:
# Text(0.5, 0.98, 'Count the locals in each hotel')

# %% [markdown]
# We found that most of the people aren't locals. And that the locals go to both hotels almost equally.

# %%
# Count how many are from each country.
hotel_bookings_not_canceled['country'].value_counts().head(10)
# Out:
# PRT    21492
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# IRL     2543
# ITA     2433
# BEL     1868
# NLD     1717
# USA     1596
# Name: country, dtype: int64

# %% [markdown]
# Although in general there are more non-locals than locals, when we look at each country by itself, we see that Portugal is in first place, which means that relatively there are the most locals.

# %%
# Create a catplot to count the market segment column for each hotel.
sns.catplot(data=hotel_bookings_not_canceled, x = 'market_segment', kind = 'count', height = 5, hue= 'hotel')
plt.xticks(rotation = 90)
plt.suptitle("Count the market segment for each hotel")
plt.show()

# %% [markdown]
# The catplot shows that the most popular market segment for both hotels is online TA. The least popular are aviation and complementary. The direct is more popular in the Resort Hotel.

# %%
#Create a point catplot to see the yearly price fluctuation.
sns.catplot(data=hotel_bookings_not_canceled, x='arrival_date_month', y = 'adr', hue='hotel', kind='point')
plt.suptitle('Yearly Price Fluctuation')
# Out:
# Text(0.5, 0.98, 'Yearly Price Fluctuation')

# %% [markdown]
# The catplot shows that August is much more expensive in the Resort Hotel, and January and November are the cheapest months. In the City Hotel, May is the most expensive month, and January is the cheapest month. The cheapest price in the City Hotel is more expensive than the cheapest price in the Resort Hotel, but the highest price in the Resort Hotel is much more expensive than the highest price in the City Hotel.

# %%
#Create a violin plot to find the meals according to the price.
sns.violinplot(data=hotel_bookings_not_canceled, x="meal" ,y="adr")
plt.ylim(0,600)
plt.suptitle("Meals According to Price")
# Out:
# Text(0.5, 0.98, 'Meals According to Price')

# %% [markdown]
# The violin plot shows that many people didn't book any meals, and that the median of FB is the lowest.

# %% [markdown]
# Conclusions:
# City Hotel is more popular than Resort Hotel. The highest season in both hotels is August and then it's much more expensive in the Resort Hotel. The year with the most bookings in both hotels is 2016. as the lead time is later there are more booking changes. Most of the guests are repeated guests. The most popular distribution channel is TA/TO. Most of the customers are Transient. Most of the people aren't locals, and the locals go to both hotels almost equally. but in relative to other countries most of the people are locals. The most popular market segment for both hotels is online TA. many people didn't book any meals.
