# %% [markdown]
# ## Seaborn Guided Project
# #### Shoshi Finkel

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
hotel_bookings = pd.read_csv("hotel_bookings.csv")

# %%
# Explore the data
hotel_bookings.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hotel_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Find the nulls values
hotel_bookings.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# Dropping the company and the agent columns, they seems unrelavent becouse they have a lot of nulls.
hotel_bookings.drop(hotel_bookings[['company', 'agent']], axis=1, inplace=True)

# %%
# Check the changes
hotel_bookings.shape
# Out:
# (119390, 30)

# %%
hotel_bookings['country'] =hotel_bookings['country'].fillna('Unknown')

# %%
hotel_bookings['country'].isnull().sum()
# Out:
# 0

# %%
hotel_bookings['children'] =hotel_bookings['children'].fillna(0)

# %%
hotel_bookings['children'].isnull().sum()
# Out:
# 0

# %%
hotel_bookings['arrival_date_month'] = hotel_bookings['arrival_date_month'].map({'January' : 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November': 11, 'December':12})

# %%
hotel_bookings['arrival_date'] =pd.to_datetime(dict(year=hotel_bookings.arrival_date_year, month=hotel_bookings.arrival_date_month, day=hotel_bookings.arrival_date_day_of_month))

# %%
sns.heatmap(data=hotel_bookings[['lead_time','is_canceled']].corr(),annot=True, cmap='Purples')
plt.suptitle("Lead time Impacting Cancellations")
# Out:
# Text(0.5, 0.98, 'Lead time Impacting Cancellations')

# %%
hotel_bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'arrival_date'],
#       dtype='object')

# %%
sns.catplot(data = hotel_bookings, x = 'arrival_date_month', kind= 'count',palette='rainbow')
plt.suptitle("Booking Per Month")
# Out:
# Text(0.5, 0.98, 'Booking Per Month')

# %%
sns.catplot(data = hotel_bookings, x = 'arrival_date_year', kind= 'count',palette='rainbow')
plt.suptitle("Booking Per Year")
# Out:
# Text(0.5, 0.98, 'Booking Per Year')

# %%
def local(x):
    if x == 'PRT':
        return 'local'
    else:
        return 'Out of town'

# %%
hotel_bookings['local'] = hotel_bookings['country'].apply(local)

# %%
sns.catplot(data=hotel_bookings, x='local', kind='count', hue='hotel')

# %%
#count = hotel_bookings['country'].value_counts().head(10)

# %%
#sns.catplot(data=count,x=count.index,kind=count.values )

# %%
sns.relplot(data=hotel_bookings, x="lead_time", y="booking_changes",hue = 'customer_type', style='distribution_channel', size='is_repeated_guest', col='hotel',
 sizes= (15, 200))
plt.suptitle("Booking Per Year")
plt.show()

# %%
sns.lmplot(x="lead_time", y="arrival_date_month", col='hotel', hue='local', row='meal', height=3,  data=hotel_bookings)

# %%
sns.catplot(data=hotel_bookings, x = 'market_segment', kind = 'count', height = 5, hue= 'hotel')
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Direct'),
#   Text(1, 0, 'Corporate'),
#   Text(2, 0, 'Online TA'),
#   Text(3, 0, 'Offline TA/TO'),
#   Text(4, 0, 'Complementary'),
#   Text(5, 0, 'Groups'),
#   Text(6, 0, 'Undefined'),
#   Text(7, 0, 'Aviation')])

# %%
sns.catplot(data=hotel_bookings, x = 'customer_type', kind = 'count', height = 5, hue= 'hotel')

# %%
sns.catplot(data=hotel_bookings, x='arrival_date_month', y = 'adr', hue='hotel', kind='point')
plt.suptitle('Yearly Price Fluctuation')
# Out:
# Text(0.5, 0.98, 'Yearly Price Fluctuation')

# %%
sns.violinplot(data=hotel_bookings, x="meal" ,y="adr")
plt.ylim(0,800)
# Out:
# (0.0, 800.0)
